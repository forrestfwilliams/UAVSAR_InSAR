# %% [markdown]
# # UAVSAR Interferogram Processing

# %% [markdown]
# ## Setup

# %%
import glob
import os
import stat
import sys
from datetime import datetime
import itertools

# %%
cd /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2
# Out:
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2

# %% [markdown]
# ## Download UAVSAR SLC files
# Unfortunately, downloading directly to the jpl server results in in a `connection denied` error, so the files must first be downloaded to the local machine, then transferred to the JPL server via the secure copy program (`scp`)

# %%
# Create the batch script for downloading the data
with open('Haywrd_0550201.sh','r') as f:
    lines = f.readlines()

files = [x.split(' ')[1][:-1] for x in lines]
names = [x.split('/')[-1] for x in files]

batch_lines = ['@ECHO OFF\n'] + [f'CALL CURL {x} -o {y}\n' for x,y in zip(files,names)]

with open('..\\Haywrd_0550201.bat', 'w+') as f:
    f.writelines(batch_lines)

# %%
# Create the batch script for transferring the data
complete = glob.glob('..\Hayw*')
remote_path = 'fwilliam@137.78.249.109:/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1'
transfer_lines = ['@ECHO OFF\n'] + [f'CALL scp {os.path.basename(x)} {remote_path}\n' for x in complete]
with open('..\\transfer.bat', 'w+') as f:
    f.writelines(transfer_lines)

# %% [markdown]
# ## Perform ISCE Processing

# %% [markdown]
# ### Create Run Files

# %%
ls
# Out:
# downloadHH/  Haywar_05502_01_BC.dop  JPL_internship/

# %%
# !mkdir downloadHH

# %%
# !mv Haywar* downloadHH/

# %%
# !mv downloadHH/*.dop .

# %%
# !prepareUAVSAR_coregStack.py -h
# !prepareUAVSAR_coregStack.py -i downloadHH -o SLC -d Haywar_05502_01_BC.dop -s 2
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 20091119
# downloadHH/Haywar_05502_09092_006_091119_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_09092_006_091119_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:25,555 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:25,783 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:25,784 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:25,870 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:25,871 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:25,912 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:25,912 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:25,914 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:25,914 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:25,914 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:25,914 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:25,915 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:25,915 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:25,915 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:25,915 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_09092_006_091119_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc
# mv downloadHH/Haywar_05502_09092_006_091119_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119
# 9785 66664
# 20141112
# downloadHH/Haywar_05502_14165_005_141112_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_14165_005_141112_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20141112
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:27,231 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:27,261 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:27,261 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:27,339 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:27,339 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:27,340 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:27,340 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:27,341 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:27,342 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_14165_005_141112_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20141112/20141112.slc
# mv downloadHH/Haywar_05502_14165_005_141112_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20141112
# 9785 66664
# 20121102
# downloadHH/Haywar_05502_12126_009_121102_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_12126_009_121102_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20121102
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:27,963 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:27,993 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:27,993 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:28,070 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:28,070 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:28,072 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:28,072 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:28,072 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:28,072 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:28,072 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:28,073 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:28,073 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:28,073 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:28,073 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:28,073 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_12126_009_121102_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20121102/20121102.slc
# mv downloadHH/Haywar_05502_12126_009_121102_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20121102
# 9785 66664
# 20200910
# downloadHH/Haywar_05502_20024_029_200910_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_20024_029_200910_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:28,628 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:28,643 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:28,643 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:28,689 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:28,689 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:28,690 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596148
# 2021-08-30 14:03:28,690 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:28,691 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_20024_029_200910_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910/20200910.slc
# mv downloadHH/Haywar_05502_20024_029_200910_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910
# 9785 66664
# 20090220
# downloadHH/Haywar_05502_09007_002_090220_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_09007_002_090220_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:29,300 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:29,315 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:29,315 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:29,361 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:29,361 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:29,362 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:29,362 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:29,363 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_09007_002_090220_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc
# mv downloadHH/Haywar_05502_09007_002_090220_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220
# 9785 66664
# 20100301
# downloadHH/Haywar_05502_10024_005_100301_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_10024_005_100301_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:29,946 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:29,965 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:29,966 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:30,034 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:30,034 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:30,035 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:30,035 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:30,035 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:30,035 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:30,036 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:30,036 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:30,036 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:30,036 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:30,036 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:30,036 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_10024_005_100301_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301/20100301.slc
# mv downloadHH/Haywar_05502_10024_005_100301_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301
# 9785 66664
# 20170403
# downloadHH/Haywar_05502_17044_010_170403_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_17044_010_170403_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20170403
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:30,621 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:30,637 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:30,638 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:30,686 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:30,686 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:30,687 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596148
# 2021-08-30 14:03:30,687 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:30,688 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_17044_010_170403_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20170403/20170403.slc
# mv downloadHH/Haywar_05502_17044_010_170403_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20170403
# 9785 66664
# 20110712
# downloadHH/Haywar_05502_11048_010_110712_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_11048_010_110712_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20110712
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:31,210 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:31,240 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:31,240 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:31,319 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:31,319 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:31,320 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:31,320 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:31,321 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:31,322 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_11048_010_110712_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20110712/20110712.slc
# mv downloadHH/Haywar_05502_11048_010_110712_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20110712
# 9785 66664
# 20210601
# downloadHH/Haywar_05502_21043_006_210601_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_21043_006_210601_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:31,906 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.2653225841984
# 2021-08-30 14:03:31,922 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:31,922 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:31,973 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:31,974 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.2653225841984
# 2021-08-30 14:03:31,974 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596148
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:31,975 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:31,976 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_21043_006_210601_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601/20210601.slc
# mv downloadHH/Haywar_05502_21043_006_210601_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601
# 9785 66664
# 20111103
# downloadHH/Haywar_05502_11071_004_111103_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_11071_004_111103_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20111103
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:32,661 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:32,677 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:32,677 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:32,725 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:32,725 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:32,726 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:32,726 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:32,727 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_11071_004_111103_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20111103/20111103.slc
# mv downloadHH/Haywar_05502_11071_004_111103_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20111103
# 9785 66664
# 20101110
# downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:33,356 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:33,384 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:33,385 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:33,460 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:33,460 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:33,462 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:33,462 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:33,462 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:33,462 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:33,463 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:33,463 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:33,463 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:33,463 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:33,463 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:33,463 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110/20101110.slc
# mv downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110
# 9785 66664
# 20160324
# downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20160324
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:34,143 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:34,172 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:34,173 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:34,250 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:34,250 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:34,251 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:34,252 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:34,252 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:34,252 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:34,252 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:34,252 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:34,253 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:34,253 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:34,253 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:34,253 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20160324/20160324.slc
# mv downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20160324
# 9785 66664
# 20100115
# downloadHH/Haywar_05502_10008_001_100115_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_10008_001_100115_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:34,842 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:34,858 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:34,859 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:34,908 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:34,909 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:34,909 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:34,910 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:34,911 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:34,911 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_10008_001_100115_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115/20100115.slc
# mv downloadHH/Haywar_05502_10008_001_100115_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115
# 9785 66664
# 20140528
# downloadHH/Haywar_05502_14065_007_140528_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_14065_007_140528_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20140528
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:35,526 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:35,555 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:35,556 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:35,630 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:35,631 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:35,632 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:35,632 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:35,632 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:35,633 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_14065_007_140528_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20140528/20140528.slc
# mv downloadHH/Haywar_05502_14065_007_140528_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20140528
# 9785 66664
# 20151008
# downloadHH/Haywar_05502_15150_004_151008_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_15150_004_151008_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20151008
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:36,240 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:36,269 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:36,269 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:36,346 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:36,346 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:36,347 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:36,348 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:36,348 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:36,348 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:36,348 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:36,348 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:36,349 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:36,349 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:36,349 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:36,349 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_15150_004_151008_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20151008/20151008.slc
# mv downloadHH/Haywar_05502_15150_004_151008_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20151008
# 9785 66664
# 20100423
# downloadHH/Haywar_05502_10031_004_100423_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_10031_004_100423_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:36,948 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:36,964 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:36,964 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:37,012 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:37,012 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:37,013 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:37,013 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:37,014 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_10031_004_100423_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423/20100423.slc
# mv downloadHH/Haywar_05502_10031_004_100423_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423
# 9785 66664
# 20171020
# downloadHH/Haywar_05502_17114_008_171020_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_17114_008_171020_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20171020
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:37,544 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:37,559 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:37,559 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:37,605 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:37,605 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:37,606 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596148
# 2021-08-30 14:03:37,606 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:37,606 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:37,606 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:37,606 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:37,606 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:37,607 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:37,607 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:37,607 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:37,607 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_17114_008_171020_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20171020/20171020.slc
# mv downloadHH/Haywar_05502_17114_008_171020_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20171020
# 9785 66664
# 20201007
# downloadHH/Haywar_05502_20028_005_201007_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_20028_005_201007_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:38,138 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:38,153 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:38,153 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:38,199 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:38,199 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596148
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:38,200 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:38,201 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:38,201 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_20028_005_201007_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007/20201007.slc
# mv downloadHH/Haywar_05502_20028_005_201007_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007
# 9785 66664
# 20120413
# downloadHH/Haywar_05502_12015_002_120413_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_12015_002_120413_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20120413
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:38,783 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:38,813 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:38,814 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:38,911 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:38,911 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:38,912 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-08-30 14:03:38,912 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:38,913 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_12015_002_120413_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20120413/20120413.slc
# mv downloadHH/Haywar_05502_12015_002_120413_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20120413
# 9785 66664
# 20180801
# downloadHH/Haywar_05502_18039_006_180801_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_18039_006_180801_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 2 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20180801
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-08-30 14:03:39,491 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-08-30 14:03:39,507 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-08-30 14:03:39,508 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-08-30 14:03:39,555 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-08-30 14:03:39,555 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596148
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 1
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453746796, -121.792411804
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 2
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608703613, -121.938148499
# 2021-08-30 14:03:39,556 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 3
# 2021-08-30 14:03:39,557 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.687095642, -121.349296570
# 2021-08-30 14:03:39,557 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 2 Data Approximate Corner 4
# 2021-08-30 14:03:39,557 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.848030090, -121.499282837
# mv downloadHH/Haywar_05502_18039_006_180801_L090HH_01_BC_s2_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20180801/20180801.slc
# mv downloadHH/Haywar_05502_18039_006_180801_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20180801
# 9785 66664

# %% [markdown]
# Some directory setup needs to be done before we can run `stackStripMap.py`:

# %%
ls
# Out:
# dop.txt  downloadHH/  Haywar_05502_01_BC.dop  isce.log  JPL_internship/  SLC/

# %%
# !mkdir merged

# %%
cd merged
# Out:
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged

# %%
# !ln -s ../SLC

# %%
cd ..
# Out:
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2

# %%
# !cp -r /u/sar-r0/fielding/Calif/SF_Bay/topo/USGS/1_3asec/ ./dem
# !ln -s /u/sar-r0/fielding/Calif/SF_Bay/topo/USGS/1_3asec

# %%
# !stackStripMap.py -s SLC/ -d ./1_3asec/BayArea_USGS_13.dem.wgs84 -a 8 -r 2 -W interferogram --nofocus -S uavsar_stack -t 600 --filter_strength 0.2
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Sensor is not hard-coded (ers, envisat, alos), will keep default alks
# ['/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20121102', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20141112', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20140528', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20110712', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20120413', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20151008', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20111103', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20160324', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20170403', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20171020', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20180801', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007']
# ['20090220', '20091119', '20100115', '20100301', '20100423', '20101110', '20110712', '20111103', '20120413', '20121102', '20140528', '20141112', '20151008', '20160324', '20170403', '20171020', '20180801', '20200910', '20201007', '20210601']
# reference date was not found. The first acquisition will be considered as the stack reference date.
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# 20091119  :  0.0
# 20100115  :  0.0
# 20100301  :  0.0
# 20100423  :  0.0
# 20101110  :  0.0
# 20110712  :  0.0
# 20111103  :  0.0
# 20120413  :  0.0
# 20121102  :  0.0
# 20140528  :  0.0
# 20141112  :  0.0
# 20151008  :  0.0
# 20160324  :  0.0
# 20170403  :  0.0
# 20171020  :  0.0
# 20180801  :  0.0
# 20200910  :  0.0
# 20201007  :  0.0
# 20210601  :  0.0
# ##################
# SLCs with min degree connection of 2.0
# 20180801
# 20200910
# 20201007
# 20210601
# ##################
# Traceback (most recent call last):
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/stackStripMap.py", line 367, in <module>
#     main(sys.argv[1:])
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/stackStripMap.py", line 338, in main
#     pairs = selectPairs(inps,stackReferenceDate, secondaryDates, acquisitionDates,doBaselines=False)
#   File "/u/sarh0/fwilliam/tools/isce2/contrib/stack/stripmapStack/Stack.py", line 757, in selectPairs
#     plotNetwork(baselineDict, timeDict, pairs,os.path.join(inps.workDir,'pairs.pdf'))
#   File "/u/sarh0/fwilliam/tools/isce2/contrib/stack/stripmapStack/Stack.py", line 810, in plotNetwork
#     raise Exception('The network for cascading coregistration   is not connected')
# Exception: The network for cascading coregistration   is not connected

# %% [markdown]
# It looks like 600 is not a large enough time delta to create a connected network, lets determine what the minimum time delta needed is:

# %%
d = ['20090220', '20091119', '20100115', '20100301', '20100423', '20101110', '20110712', '20111103', '20120413', '20121102', '20140528', '20141112', '20151008', '20160324', '20170403', '20171020', '20180801', '20200910', '20201007', '20210601']
dates = [datetime.strptime(x,'%Y%m%d') for x in d]
dates.sort()
difference = [x-y for x,y in zip(dates,[dates[0]]+dates[0:-1])]
max(difference)
# Out:
# datetime.timedelta(771)

# %%
# !stackStripMap.py -s SLC/ -d ./DEM/BayArea_USGS_13.dem.wgs84 -a 8 -r 2 -W interferogram --nofocus -S uavsar_stack -t 800 --filter_strength 0.2
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Sensor is not hard-coded (ers, envisat, alos), will keep default alks
# ['/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20121102', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20141112', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20140528', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20110712', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20120413', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20151008', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20111103', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20160324', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20170403', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20171020', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20180801', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007']
# ['20090220', '20091119', '20100115', '20100301', '20100423', '20101110', '20110712', '20111103', '20120413', '20121102', '20140528', '20141112', '20151008', '20160324', '20170403', '20171020', '20180801', '20200910', '20201007', '20210601']
# reference date was not found. The first acquisition will be considered as the stack reference date.
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# 20091119  :  0.0
# 20100115  :  0.0
# 20100301  :  0.0
# 20100423  :  0.0
# 20101110  :  0.0
# 20110712  :  0.0
# 20111103  :  0.0
# 20120413  :  0.0
# 20121102  :  0.0
# 20140528  :  0.0
# 20141112  :  0.0
# 20151008  :  0.0
# 20160324  :  0.0
# 20170403  :  0.0
# 20171020  :  0.0
# 20180801  :  0.0
# 20200910  :  0.0
# 20201007  :  0.0
# 20210601  :  0.0
# ##################
# SLCs with min degree connection of 2.0
# 20210601
# ##################
# number of pairs:  56
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_01_reference
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_02_focus_split
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_03_geo2rdr_coarseResamp
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_04_refineSecondaryTiming
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_05_invertMisreg
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_06_fineResamp
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_07_grid_baseline
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/run_files/run_08_igram

# %%
ls run_files
# Out:
# run_01_reference                  run_05_invertMisreg
# run_01_reference.job              run_05_invertMisreg.job
# run_02_focus_split                run_06_fineResamp
# run_02_focus_split.job            run_06_fineResamp.job
# run_03_geo2rdr_coarseResamp       run_07_grid_baseline
# run_03_geo2rdr_coarseResamp.job   run_07_grid_baseline.job
# run_04_refineSecondaryTiming      run_08_igram
# run_04_refineSecondaryTiming.job  run_08_igram.job

# %%
# !run.py -h
# Out:
# usage: run.py [-h] -i INPUT [-p PROCESSORS]
#
# Preparing input rdf and processing workflow for phase unwrapping
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INPUT, --input INPUT
#                         input run file which contains multiple commands to be
#                         run. Each line is assumed to be a command that can be
#                         run independent of other commands
#   -p PROCESSORS, --number_of_processors PROCESSORS
#                         number of processors

# %%
# !nproc
# Out:
# 32

# %% [markdown]
# ### Excecute Run Files
#
# For long-running scripts, it's better to run the commands within a shell with nohup specified instead of from inside the notebook because jupyter lab does not handle ssh disconnections well. Also, for **UAVSAR data only steps 1 and 8 need to be run** (coregister DEM and create interferograms). The cell below generates two .tsch that run each respectively and log the results. Copy the lines printed by this cell, then run them in the shell.

# %%
wd = os.getcwd()

header = """#! /bin/tcsh

date
#Start time
#begin=`date +"%s"`

# RUN
"""

master = f'nohup source {os.path.join(wd,"run_files","run_01_reference")} > master.log'
igrams = f'nohup source {os.path.join(wd,"run_files","run_08_igram")} > igrams.log'

footer = """

# Print time after running
#echo Walltime : $(expr `date +"%s"` - $begin)          # Seconds
date
"""

cmds = {'master':master,'igrams':igrams}
for key in cmds:
    name = f'run-{key}.tcsh' 
    with open(name, 'w') as f:
        f.write(header)
        f.write(cmds[key])
        f.write(footer)
    st = os.stat(name)
    os.chmod(name, st.st_mode | stat.S_IEXEC)
    print(f'./{name} ; python JPL_internship/emailme.py')
# Out:
# ./run-master.tcsh ; python JPL_internship/emailme.py
# ./run-igrams.tcsh ; python JPL_internship/emailme.py

# %% [markdown]
# ### Step 1 Log
# Took about 30 minutes to run

# %%
cat master.log
# Out:
# Completed Parsing the Configuration file
# Running: topo
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220', '--dem', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/DEM/BayArea_USGS_13.dem.wgs84', '--output', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference', '--alks', '8', '--rlks', '2', '--native']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# CPU mode
# 2021-08-31 18:51:18,167 - isce.zerodop.topozero - WARNING - Default Peg heading set to: 0.9668732197905483
# Polynomial Order: 0 - by - 6
# 72.8806	-0.0394231	1.06909e-05	-2.19529e-09	2.81772e-13	-1.95365e-17	5.54178e-22
# Polynomial Order: 0 - by - 1
# 13340.5	1.66551
# GDAL open (R): /u/sar-r0/fielding/Calif/SF_Bay/topo/USGS/1_3asec/BayArea_USGS_13.dem.wgs84.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lat.rdr
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lon.rdr
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/los.rdr
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/incLocal.rdr
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/shadowMask.rdr
#  Initializing biquintic interpolator
#  Orbit interpolation method: hermite
#  Max threads used:           32
#  DEM parameters:
#  Dimensions:        21612       32412
#  Top Left:   -123.00000000000000        39.000000000000000
#  Spacing:    9.2592592749776804E-005  -9.2592592749776804E-005
#  Lon:   -123.00000000000000       -120.99898147808457
#  Lat:    35.998981476386987        39.000000000000000
#
#  Estimated DEM bounds needed for global height range:
#  Lon:   -122.10346980800827       -121.25357311737520
#  Lat:    37.284847513460981        37.981498396669998
#
#  Actual DEM bounds used:
#  Dimensions:         9180        7526
#  Top Left:   -122.10351851699666        37.981574072345204
#  Spacing:    9.2592592749776804E-005  -9.2592592749776804E-005
#  Lon:   -122.10351851699666       -121.25361110814646
#  Lat:    37.284814811903132        37.981574072345204
#  Lines:        11000       18525
#  Pixels:         9683       18862
#  Max DEM height:    1335.68726
#  Primary iterations:           25
#  Secondary iterations:           10
#  Distance threshold :    5.0000000000000003E-002
#  Processing line:            1   285.10458460884689
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         1001   285.10458460884780
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         2001   285.10458460884809
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         3001   285.10458460884865
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         4001   285.10458460884831
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         5001   285.10458460884900
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         6001   285.10458460884860
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         7001   285.10458460884490
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         8001   285.10458460884735
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:         9001   285.10458460884746
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        10001   285.10458460884399
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        11001   285.10458460884314
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        12001   285.10458460884666
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        13001   285.10458460884564
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        14001   285.10458460884519
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        15001   285.10458460884854
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        16001   285.10458460884882
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        17001   285.10458460884536
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        18001   285.10458460884615
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        19001   285.10458460884729
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        20001   285.10458460884854
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        21001   285.10458460884530
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        22001   285.10458460884712
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        23001   285.10458460884752
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        24001   285.10458460884701
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        25001   285.10458460884820
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        26001   285.10458460884689
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        27001   285.10458460884627
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        28001   285.10458460884701
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        29001   285.10458460884632
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        30001   285.10458460884689
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        31001   285.10458460884803
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        32001   285.10458460884530
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        33001   285.10458460884507
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        34001   285.10458460884763
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        35001   285.10458460884865
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        36001   285.10458460884644
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        37001   285.10458460884797
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        38001   285.10458460884678
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        39001   285.10458460884678
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        40001   285.10458460884541
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        41001   285.10458460884524
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        42001   285.10458460884837
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        43001   285.10458460884570
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        44001   285.10458460884536
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        45001   285.10458460884740
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        46001   285.10458460884746
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        47001   285.10458460884678
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        48001   285.10458460884729
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lat.rdr
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lat.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lat.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lon.rdr
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lon.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lon.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/los.rdr
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/los.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/los.rdr
# GDAL close: /u/sar-r0/fielding/Calif/SF_Bay/topo/USGS/1_3asec/BayArea_USGS_13.dem.wgs84.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/incLocal.rdr
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/incLocal.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/incLocal.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/shadowMask.rdr
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/shadowMask.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/shadowMask.rdr
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/simamp.rdr
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/simamp.rdr
# C pointer already created. Finalize and recreate if image dimensions changed.
# C pointer already created. Finalize and recreate if image dimensions changed.
# --------------------------------------------------
# generate multilooked geometry files with alks=8 and rlks=2 using gdal.Translate() ...
# multilook /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/hgt.rdr
# multilook /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/incLocal.rdr
# multilook /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lat.rdr
# multilook /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/lon.rdr
# multilook /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/los.rdr
# multilook /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/geom_reference/shadowMask.rdr
# Running: createWaterMask
# ['--dem_file', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/DEM/BayArea_USGS_13.dem.wgs84', '--lat_file', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/geom_reference/lat.rdr', '--lon_file', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/geom_reference/lon.rdr', '--output', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/geom_reference/waterMask.rdr']
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N38W123.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N38W122.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N38W121.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N37W123.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N37W122.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N37W121.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N36W123.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N36W122.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N36W121.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N35W123.SRTMSWBD.raw.zip
# 2021-08-31 19:12:47,836 - isce.iscesys.DataRetriever - WARNING - There was a problem in retrieving the file  http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N35W123.SRTMSWBD.raw.zip. Requested file seems not present on server.
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/DEM/swbdLat_N35_N39_Lon_W123_W120.wbd
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/DEM/swbdLat_N35_N39_Lon_W123_W120.wbd
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/geom_reference/waterMask.rdr
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/geom_reference/waterMask.rdr
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N35W122.SRTMSWBD.raw.zip
# command = curl -n  -L -c $HOME/.earthdatacookie -b $HOME/.earthdatacookie -k -f -O http://e4ftl01.cr.usgs.gov/MEASURES/SRTMSWBD.003/2000.02.11/N35W121.SRTMSWBD.raw.zip
# Writing geotrans to VRT for /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/DEM/swbdLat_N35_N39_Lon_W123_W120.wbd
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        49001   285.10458460884735
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        50001   285.10458460884695
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        51001   285.10458460884780
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        52001   285.10458460884797
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        53001   285.10458460884871
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        54001   285.10458460884826
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        55001   285.10458460884900
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        56001   285.10458460884865
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        57001   285.10458460884439
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        58001   285.10458460884792
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        59001   285.10458460884644
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        60001   285.10458460884388
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        61001   285.10458460884536
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        62001   285.10458460884666
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        63001   285.10458460884632
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        64001   285.10458460884689
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        65001   285.10458460884854
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Processing line:        66001   285.10458460884570
#  Dopplers:    72.880606767595935       -6.8944848609771734       -28.930641473128389
#  Total convergence:   495230226  out of    652307240

# %% [markdown]
# ### Step 8 Log
# This step took 57 hours to complete (~1 hour per interferogram)

# %%
n_pairs = 56
with open('igrams.log','r') as f:
    lines = f.readlines()

n_completions = len([x for x in lines if '*** Normal Completion  ***' in x])

if n_pairs == n_completions:
    print('All interferograms completed successfully!')
else:
    
    print(f'There was a problem with the run :( {n_completions} interferograms done.')
# Out:
# All interferograms completed successfully!

# %%
cat igrams.log
# Out:
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20091119/20091119.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.cor', '--strength', '0.2']
# 2021-08-31 19:15:59,445 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int
# 2021-08-31 19:15:59,464 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-08-31 19:15:59,464 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-08-31 19:15:59,464 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int
# 2021-08-31 19:15:59,464 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int
# 2021-08-31 19:15:59,465 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-08-31 19:15:59,465 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/20090220_20091119.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int
# 2021-08-31 19:16:18,735 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20091119/filt_20090220_20091119_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115/20100115.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115/20100115.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20100115/20100115.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.cor', '--strength', '0.2']
# 2021-08-31 20:03:51,066 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int
# 2021-08-31 20:03:51,074 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-08-31 20:03:51,074 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-08-31 20:03:51,075 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int
# 2021-08-31 20:03:51,075 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int
# 2021-08-31 20:03:51,075 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-08-31 20:03:51,075 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/20090220_20100115.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int
# 2021-08-31 20:04:10,242 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100115/filt_20090220_20100115_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301/20100301.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301/20100301.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20100301/20100301.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.cor', '--strength', '0.2']
# 2021-08-31 20:46:17,344 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int
# 2021-08-31 20:46:17,352 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-08-31 20:46:17,352 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-08-31 20:46:17,352 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int
# 2021-08-31 20:46:17,352 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int
# 2021-08-31 20:46:17,352 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-08-31 20:46:17,352 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/20090220_20100301.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int
# 2021-08-31 20:46:36,291 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100301/filt_20090220_20100301_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423/20100423.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100423/20100423.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20100423/20100423.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.cor', '--strength', '0.2']
# 2021-08-31 21:37:57,182 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int
# 2021-08-31 21:37:57,189 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-08-31 21:37:57,189 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-08-31 21:37:57,189 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int
# 2021-08-31 21:37:57,189 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int
# 2021-08-31 21:37:57,189 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-08-31 21:37:57,190 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/20090220_20100423.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int
# 2021-08-31 21:38:16,426 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20100423/filt_20090220_20100423_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110/20101110.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20101110/20101110.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/20090220.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20101110/20101110.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.cor', '--strength', '0.2']
# 2021-08-31 22:37:43,324 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int
# 2021-08-31 22:37:43,332 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-08-31 22:37:43,332 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-08-31 22:37:43,332 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int
# 2021-08-31 22:37:43,332 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int
# 2021-08-31 22:37:43,332 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-08-31 22:37:43,332 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/20090220_20101110.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int
# 2021-08-31 22:38:02,311 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20090220_20101110/filt_20090220_20101110_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115/20100115.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100115/20100115.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20091119/20091119.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20100115/20100115.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.cor', '--strength', '0.2']
# 2021-08-31 23:33:11,913 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int
# 2021-08-31 23:33:11,921 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-08-31 23:33:11,921 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-08-31 23:33:11,921 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int
# 2021-08-31 23:33:11,921 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int
# 2021-08-31 23:33:11,921 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-08-31 23:33:11,921 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/20091119_20100115.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int
# 2021-08-31 23:33:30,363 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100115/filt_20091119_20100115_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301/20100301.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20091119/20091119.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20100301/20100301.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20091119/20091119.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20100301/20100301.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/filt_20091119_20100301.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/filt_20091119_20100301.cor', '--strength', '0.2']
# 2021-09-01 00:11:27,887 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20091119_20100301/20091119_20100301.int.vrt
# ...
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910/20200910.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601/20210601.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20200910/20200910.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601/20210601.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20200910/20200910.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20210601/20210601.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.cor', '--strength', '0.2']
# 2021-09-02 20:59:43,668 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int
# 2021-09-02 20:59:43,675 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-09-02 20:59:43,675 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-09-02 20:59:43,675 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int
# 2021-09-02 20:59:43,675 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int
# 2021-09-02 20:59:43,675 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-09-02 20:59:43,675 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/20200910_20210601.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int
# 2021-09-02 21:00:02,028 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20200910_20210601/filt_20200910_20210601_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
#
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007/20201007.slc.vrt
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601/20210601.slc.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.amp
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int
# API open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.amp
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.amp
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20201007/20201007.slc.vrt
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20210601/20210601.slc.vrt
# Completed Parsing the Configuration file
# Running: crossmul
# ['--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20201007/20201007.slc', '--secondary', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/merged/SLC/20210601/20210601.slc', '--outdir', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601', '--alks', '8', '--rlks', '2']
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Completed set State
# Running: FilterAndCoherence
# ['--input', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int', '--filt', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.cor', '--strength', '0.2']
# 2021-09-02 21:40:32,272 - isce.tops.runFilter - INFO - Applying power-spectral filter
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int
# 2021-09-02 21:40:32,279 - isce.mroipac.filter - DEBUG - width: 4892
# 2021-09-02 21:40:32,279 - isce.mroipac.filter - DEBUG - length: 8333
# 2021-09-02 21:40:32,279 - isce.mroipac.filter - DEBUG - input: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int
# 2021-09-02 21:40:32,279 - isce.mroipac.filter - DEBUG - output: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int
# 2021-09-02 21:40:32,279 - isce.mroipac.filter - DEBUG - filter strength: 0.2
# 2021-09-02 21:40:32,279 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  4892  8333     0
#
# number of lines written to file: 8336
# Rescaling magnitude
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/20201007_20210601.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int
# 2021-09-02 21:40:50,813 - isce.tops.runFilter - INFO - Estimating spatial coherence based phase sigma
# GDAL open (R): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int.vrt
# API open (WR): /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.cor
# GDAL close: /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int.vrt
# API close:  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.cor
#
# snaphu v1.4.2
# Reading wrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601_snaphu.unw
#
# snaphu v1.4.2
# Running: unwrap
# ['--ifg', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.int', '--coh', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.cor', '--unwprefix', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601', '--reference', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/SLC/20090220/data', '--defomax', '2', '--alks', '8', '--rlks', '2', '--method', 'snaphu']
# snaphu
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/referenceShelve/data
# unwrapping method :  snaphu
# Growing connected components on second pass
# Reading unwrapped phase from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601_snaphu.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S2/Igrams/20201007_20210601/filt_20201007_20210601_snaphu.unw.conncomp
#  Max threads used:           32
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       66664        8192           9
#
#  << PS filtering >>
#
#
#  interferogram width:  4892  number of lines/patch:  3700
#  start line:        1  number of lines:    8333
#  start sample:      1  end sample:         4892
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  3
#
#  PATCH:   1   starting line:     0    lines read: 3700
#  starting output line:    1   ending output line: 3568
#
#  PATCH:   2   starting line:  3436    lines read: 3700
#  starting output line:  133   ending output line: 3568
#
#  PATCH:   3   starting line:  6872    lines read: 1461
#  starting output line:  133   ending output line: 1461
#
# *** Normal Completion  ***
