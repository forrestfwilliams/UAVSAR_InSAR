# %% [markdown]
# # UAVSAR Interferogram Processing

# %% [markdown]
# ## Setup

# %%
import glob
import os
import sys
from datetime import datetime
import itertools

# %%
cd /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1
# Out:
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1

# %% [markdown]
# ## Download UAVSAR SLC files
# Unfortunately, downloading directly to the jpl server results in in a `connection denied` error, so the files must first be downloaded to the local machine, then transferred to the JPL server via the secure copy program (`scp`)

# %%
# Create the batch script for downloading the data
with open('Haywrd_0550201.sh','r') as f:
    lines = f.readlines()

files = [x.split(' ')[1][:-1] for x in lines]
names = [x.split('/')[-1] for x in files]

batch_lines = ['@ECHO OFF\n'] + [f'CALL CURL {x} -o {y}\n' for x,y in zip(files,names)]

with open('..\\Haywrd_0550201.bat', 'w+') as f:
    f.writelines(batch_lines)

# %%
# Create the batch script for transferring the data
complete = glob.glob('..\Hayw*')
remote_path = 'fwilliam@137.78.249.109:/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1'
transfer_lines = ['@ECHO OFF\n'] + [f'CALL scp {os.path.basename(x)} {remote_path}\n' for x in complete]
with open('..\\transfer.bat', 'w+') as f:
    f.writelines(transfer_lines)

# %% [markdown]
# ## Perform ISCE Processing

# %% [markdown]
# ### Create Run Files

# %%
# !mkdir downloadHH

# %%
# !mv Haywar* downloadHH/

# %%
# !mv downloadHH/*.dop .

# %%
# !prepareUAVSAR_coregStack.py -h
# !prepareUAVSAR_coregStack.py -i downloadHH -o SLC -d Haywar_05502_01_BC.dop
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 20101110
# downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 1 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20101110
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-07-27 20:42:23,293 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-07-27 20:42:23,324 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-07-27 20:42:23,325 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-07-27 20:42:23,403 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-07-27 20:42:23,403 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-07-27 20:42:23,445 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-07-27 20:42:23,446 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-07-27 20:42:23,447 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 1
# 2021-07-27 20:42:23,447 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.250137329, -122.164855957
# 2021-07-27 20:42:23,447 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 2
# 2021-07-27 20:42:23,447 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.403179169, -122.309753418
# 2021-07-27 20:42:23,447 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 3
# 2021-07-27 20:42:23,448 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453689575, -121.792434692
# 2021-07-27 20:42:23,448 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 4
# 2021-07-27 20:42:23,448 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608684540, -121.938209534
# mv downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC_s1_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20101110/20101110.slc
# mv downloadHH/Haywar_05502_10080_003_101110_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/
- isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 2
# 2021-07-27 20:42:35,280 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.403179169, -122.309753418
# 2021-07-27 20:42:35,280 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 3
# 2021-07-27 20:42:35,281 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453689575, -121.792434692
# 2021-07-27 20:42:35,281 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 4
# 2021-07-27 20:42:35,281 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608684540, -121.938209534
# mv downloadHH/Haywar_05502_10008_001_100115_L090HH_01_BC_s1_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100115/20100115.slc
# mv downloadHH/Haywar_05502_10008_001_100115_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100115
# 9785 66664
# 20160324
# downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC.ann
# unpackFrame_UAVSAR.py -i downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC.ann -d Haywar_05502_01_BC.dop -s 1 -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20160324
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# UnknownUnitWarning: (1.0)
# 2021-07-27 20:42:35,803 - isce.Sensor.UAVSAR_Stack - INFO - extractDoppler: rho0, drho, prf = 13340.4714, 1.66551366, 474.26528884506126
# 2021-07-27 20:42:35,818 - isce.Sensor.UAVSAR_Stack - INFO - coeffs = [ 1.60615571e+00 -8.68813193e-04  2.35607232e-07 -4.83802877e-11
#   6.20973191e-15 -4.30547864e-19  1.22130811e-23]
# 2021-07-27 20:42:35,819 - isce.Sensor.UAVSAR_Stack - INFO - rms residual = [0.00162272]
# 2021-07-27 20:42:35,865 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: self.dopplerVals = {'Near': 1.6061557138716118}
# 2021-07-27 20:42:35,865 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack.extractDoppler: prf = 474.26528884506126
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: peg radius of curvature = 6377528.189596922
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - UAVSAR_Stack: terrain height = 272.265009
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 1
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.250137329, -122.164855957
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 2
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.403179169, -122.309753418
# 2021-07-27 20:42:35,866 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 3
# 2021-07-27 20:42:35,867 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.453689575, -121.792434692
# 2021-07-27 20:42:35,867 - isce.Sensor.UAVSAR_Stack - INFO - key = Segment 1 Data Approximate Corner 4
# 2021-07-27 20:42:35,867 - isce.Sensor.UAVSAR_Stack - INFO - metadata[key] = 37.608684540, -121.938209534
# mv downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC_s1_1x1.slc /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20160324/20160324.slc
# mv downloadHH/Haywar_05502_16032_006_160324_L090HH_01_BC.ann /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20160324
# 9785 66664

# %% [markdown]
# Some directory setup needs to be done before we can run `stackStripMap.py`:

# %%
ls
# Out:
# dem/     downloadHH/         Haywar_05502_01_BC.dop  JPL_internship/  SLC/
# dop.txt  geom_reference_v1/  isce.log                raw_data.zip

# %%
# !mkdir merged

# %%
cd merged
# Out:
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/merged

# %%
# !ln -s ../SLC

# %%
cd ..
# Out:
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1

# %%
# !cp -r /u/sar-r0/fielding/Calif/SF_Bay/topo/USGS/1_3asec/ ./dem

# %%
# !stackStripMap.py -s SLC/ -d ./DEM/BayArea_USGS_13.dem.wgs84 -a 8 -r 2 -W interferogram --nofocus -S uavsar_stack -t 600 --filter_strength 0.2
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Sensor is not hard-coded (ers, envisat, alos), will keep default alks
# ['/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100115', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20200910', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20170403', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20090220', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20171020', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20180801', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20201007', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100301', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20160324', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20111103', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100423', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20121102', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20141112', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20140528', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20101110', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20110712', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20091119', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20151008', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20120413']
# ['20090220', '20091119', '20100115', '20100301', '20100423', '20101110', '20110712', '20111103', '20120413', '20121102', '20140528', '20141112', '20151008', '20160324', '20170403', '20171020', '20180801', '20200910', '20201007']
# reference date was not found. The first acquisition will be considered as the stack reference date.
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# 20091119  :  0.0
# 20100115  :  0.0
# 20100301  :  0.0
# 20100423  :  0.0
# 20101110  :  0.0
# 20110712  :  0.0
# 20111103  :  0.0
# 20120413  :  0.0
# 20121102  :  0.0
# 20140528  :  0.0
# 20141112  :  0.0
# 20151008  :  0.0
# 20160324  :  0.0
# 20170403  :  0.0
# 20171020  :  0.0
# 20180801  :  0.0
# 20200910  :  0.0
# 20201007  :  0.0
# ##################
# SLCs with min degree connection of 1.0
# 20200910
# 20201007
# ##################
# Traceback (most recent call last):
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/stackStripMap.py", line 367, in <module>
#     main(sys.argv[1:])
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/stackStripMap.py", line 338, in main
#     pairs = selectPairs(inps,stackReferenceDate, secondaryDates, acquisitionDates,doBaselines=False)
#   File "/u/sarh0/fwilliam/tools/isce2/contrib/stack/stripmapStack/Stack.py", line 757, in selectPairs
#     plotNetwork(baselineDict, timeDict, pairs,os.path.join(inps.workDir,'pairs.pdf'))
#   File "/u/sarh0/fwilliam/tools/isce2/contrib/stack/stripmapStack/Stack.py", line 810, in plotNetwork
#     raise Exception('The network for cascading coregistration   is not connected')
# Exception: The network for cascading coregistration   is not connected

# %% [markdown]
# It looks like 600 is not a large enough time delta to create a connected network, lets determine what the minimum time delta needed is:

# %%
d = ['20090220', '20091119', '20100115', '20100301', '20100423', '20101110', '20110712', '20111103', '20120413', '20121102', '20140528', '20141112', '20151008', '20160324', '20170403', '20171020', '20180801', '20200910', '20201007']
dates = [datetime.strptime(x,'%Y%m%d') for x in d]
dates.sort()
difference = [x-y for x,y in zip(dates,[dates[0]]+dates[0:-1])]
max(difference)
# Out:
# datetime.timedelta(771)

# %%
# !stackStripMap.py -s SLC/ -d ./DEM/BayArea_USGS_13.dem.wgs84 -a 8 -r 2 -W interferogram --nofocus -S uavsar_stack -t 800 --filter_strength 0.2
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# Sensor is not hard-coded (ers, envisat, alos), will keep default alks
# ['/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100115', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20200910', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20170403', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20090220', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20171020', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20180801', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20201007', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100301', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20160324', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20111103', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20100423', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20121102', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20141112', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20140528', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20101110', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20110712', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20091119', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20151008', '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20120413']
# ['20090220', '20091119', '20100115', '20100301', '20100423', '20101110', '20110712', '20111103', '20120413', '20121102', '20140528', '20141112', '20151008', '20160324', '20170403', '20171020', '20180801', '20200910', '20201007']
# reference date was not found. The first acquisition will be considered as the stack reference date.
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# Baseline at top/bottom: 0.000000 0.000000
# 20091119  :  0.0
# 20100115  :  0.0
# 20100301  :  0.0
# 20100423  :  0.0
# 20101110  :  0.0
# 20110712  :  0.0
# 20111103  :  0.0
# 20120413  :  0.0
# 20121102  :  0.0
# 20140528  :  0.0
# 20141112  :  0.0
# 20151008  :  0.0
# 20160324  :  0.0
# 20170403  :  0.0
# 20171020  :  0.0
# 20180801  :  0.0
# 20200910  :  0.0
# 20201007  :  0.0
# ##################
# SLCs with min degree connection of 2.0
# 20200910
# 20201007
# ##################
# number of pairs:  54
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_01_reference
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_02_focus_split
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_03_geo2rdr_coarseResamp
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_04_refineSecondaryTiming
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_05_invertMisreg
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_06_fineResamp
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_07_grid_baseline
# writing  /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/run_files/run_08_igram

# %%
ls run_files
# Out:
# run_01_reference                  run_05_invertMisreg
# run_01_reference.job              run_05_invertMisreg.job
# run_02_focus_split                run_06_fineResamp
# run_02_focus_split.job            run_06_fineResamp.job
# run_03_geo2rdr_coarseResamp       run_07_grid_baseline
# run_03_geo2rdr_coarseResamp.job   run_07_grid_baseline.job
# run_04_refineSecondaryTiming      run_08_igram
# run_04_refineSecondaryTiming.job  run_08_igram.job

# %%
# !run.py -h
# Out:
# usage: run.py [-h] -i INPUT [-p PROCESSORS]
#
# Preparing input rdf and processing workflow for phase unwrapping
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INPUT, --input INPUT
#                         input run file which contains multiple commands to be
#                         run. Each line is assumed to be a command that can be
#                         run independent of other commands
#   -p PROCESSORS, --number_of_processors PROCESSORS
#                         number of processors

# %%
# !nproc
# Out:
# 32

# %% [markdown]
# ### Excecute Run Files
#
# For long-running scripts, it's better to run the commands within a tmux shell instead of from indside the notebook because jupyter lab does not handle ssh disconnections well.

# %%
names = [x for x in glob.glob('run_files/run*') if 'job' not in x]
names.sort()
commands = [print(f'run.py -p 1 -i {x} |& tee -i log_{os.path.basename(x)}.txt ; python JPL_internship/emailme.py') for x in names]
# Out:
# run.py -p 1 -i run_files/run_01_reference |& tee -i log_run_01_reference.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_02_focus_split |& tee -i log_run_02_focus_split.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_03_geo2rdr_coarseResamp |& tee -i log_run_03_geo2rdr_coarseResamp.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_04_refineSecondaryTiming |& tee -i log_run_04_refineSecondaryTiming.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_05_invertMisreg |& tee -i log_run_05_invertMisreg.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_06_fineResamp |& tee -i log_run_06_fineResamp.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_07_grid_baseline |& tee -i log_run_07_grid_baseline.txt ; python JPL_internship/emailme.py
# run.py -p 1 -i run_files/run_08_igram |& tee -i log_run_08_igram.txt ; python JPL_internship/emailme.py

# %%
# sys.path.insert(0,'/home/fwilliam/tools/isce2/contrib/stack')
# from stripmapStack import geo2rdr

# %%
# !geo2rdr.py -a 8 -r 2 -m /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_0f5502_01-S1/SLC/20090220 -s /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20201007 -g /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/merged/geom_reference -n -o /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/offsets/20201007
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20201007
# CPU mode
# /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20201007/data
# Traceback (most recent call last):
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/geo2rdr.py", line 335, in <module>
#     main()
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/geo2rdr.py", line 328, in main
#     alks=inps.alks, rlks=inps.rlks)
#   File "/home/fwilliam/tools/isce2/contrib/stack/stripmapStack/geo2rdr.py", line 216, in runGeo2rdrCPU
#     grdr.length = info.getImage().getLength()
#   File "/u/sar-r2/fwilliam/miniconda3/envs/isce2/lib/python3.6/site-packages/isce/components/isceobj/Util/decorators.py", line 290, in use_api_decorator
#     ret = func(*args,**kwargs)
#   File "/u/sar-r2/fwilliam/miniconda3/envs/isce2/lib/python3.6/site-packages/isce/components/isceobj/Image/Image.py", line 627, in getLength
#     self.coord2.coordSize = self.getFileLength()
#   File "/u/sar-r2/fwilliam/miniconda3/envs/isce2/lib/python3.6/site-packages/isce/components/iscesys/ImageApi/DataAccessorPy.py", line 200, in getFileLength
#     self.initAccessor(self.filename, 'read', int(self.width),
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
ls /u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20201007
# Out:
# 20201007.slc      data.bak  Haywar_05502_20028_005_201007_L090HH_01_BC.ann
# 20201007.slc.vrt  data.dat
# 20201007.slc.xml  data.dir

# %%
# !prepareUAVSAR_coregStack.py -h
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# usage: prepareUAVSAR_coregStack.py [-h] -i INPUT -d DOPFILE -o OUTPUT
#                                    [-s SEGMENT] [-t TEXT_CMD]
#
# Prepare UAVSAR SLC Stack files.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INPUT, --input INPUT
#                         directory which has all dates.
#   -d DOPFILE, --dop_file DOPFILE
#                         Doppler file for the stack. Needs to be in directory
#                         where command is run.
#   -o OUTPUT, --output OUTPUT
#                         output directory which will be used for unpacking.
#   -s SEGMENT, --segment SEGMENT
#                         segment of the UAVSAR stack to prepare. For "s2" use
#                         "2", etc. Default is "1"
#   -t TEXT_CMD, --text_cmd TEXT_CMD
#                         text command to be added to the beginning of each line
#                         of the run files. Default: source ~/.bash_profile;

# %%
import shelve
import isce
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce

# %%
f = '/u/sar-r2/fwilliam/Calif/UAVSAR/Stacks/Haywrd_05502_01-S1/SLC/20090220'
db = shelve.open(os.path.join(f, 'data'), flag='r')
info = db['frame']

# %%
info.getFarRange()
# Out:
# 29637.5225631

# %%
from isceobj import Image

# %%
print(info.getImage().getWidth())
# Out:
# None

# %%
help(info.getImage())
# Out:
# Help on RawImage in module isceobj.Image.RawImage object:
#
# class RawImage(isceobj.Image.Image.Image)
#  |  Method resolution order:
#  |      RawImage
#  |      isceobj.Image.Image.Image
#  |      iscesys.ImageApi.DataAccessorPy.DataAccessor
#  |      iscesys.Component.Configurable.Configurable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, family='', name='')
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __setstate__(self, d)
#  |
#  |  createImage(self)
#  |
#  |  getNumberGoodBytes(self)
#  |
#  |  setNumberGoodBytes(self, num)
#  |
#  |  updateParameters(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  family = 'rawimage'
#  |
#  |  parameter_list = (Parameter('dataType', public_name='DATA_TYPE', d...e...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from isceobj.Image.Image.Image:
#  |
#  |  adaptToRender = use_api_decorator(*args, **kwargs)
#  |
#  |  addDescription(self, doc)
#  |      # # This method appends the string describing the image for the user create
#  |      # # a list.
#  |      # #@param doc \c text description string describing the image in English for
#  |      # #  the user
#  |
#  |  asMemMap(self, filename)
#  |
#  |  ccopy(self, access_mode=None)
#  |
#  |  clone(self, access_mode=None)
#  |
#  |  copy(self, access_mode=None)
#  |      # Why reinventing the wheel when there is deepcopy
#  |      # # This method makes a new image sub-class object that are copies of
#  |      # # existing ones.
#  |
#  |  copy_attributes(self, other, *args)
#  |      # # New usage is: image.copy_attribute(image', *args), replacing:
#  |      # # ImageUtil.ImageUtil.ImageUtil.copyAttributes(image, image', *args)
#  |
#  |  dump = use_api_decorator(*args, **kwargs)
#  |
#  |  finalizeImage(self)
#  |      # Always call this function if  createImage() was previously invoked.
#  |      # It deletes the pointer to the object, closes the file associated with
#  |      # the object, frees memory.
#  |
#  |  getByteOrder(self)
#  |
#  |  getDeltaLatitude(self)
#  |
#  |  getDeltaLongitude(self)
#  |
#  |  getDescription(self)
#  |      # # gets the string describing the image for the user
#  |      # #@return \c text description string describing the image in English for
#  |      # # the user
#  |
#  |  getFirstLatitude(self)
#  |
#  |  getFirstLongitude(self)
#  |
#  |  getImagePointer(self)
#  |      # # This method gets the pointer associated to the DataAccessor.DataAccessor
#  |      # # object created.
#  |      # @return \c pointer pointer to the underlying DataAccessor.DataAccessor
#  |      # # object.
#  |
#  |  getImageType(self)
#  |
#  |  getLength = use_api_decorator(*args, **kwargs)
#  |
#  |  getProduct(self)
#  |
#  |  getWidth(self)
#  |
#  |  getXmax(self)
#  |
#  |  getXmin(self)
#  |
#  |  initImage(self, filename, accessmode, width, type=None, bands=None, scheme=None, caster=None)
#  |      # #
#  |      # This method initialize the Image.
#  |      # @param filename \c string the file name associated with the image.
#  |      # @param accessmode \c string access mode of the  file.
#  |      # @param bands \c int number of bands of the interleaving scheme.
#  |      # @param type \c string data type used to store the data.
#  |      # @param width \c int width of the image.
#  |      # @param scheme \c string interleaving scheme.
#  |      # @param caster \c string type of caster (ex. 'DoubleToFloat').
#  |
#  |  memMap(self, mode='r', band=None)
#  |
#  |  renderEnviHDR(self)
#  |      Renders a bare minimum ENVI HDR file, that can be used to directly ingest the outputs into
#  |      a GIS package.
#  |
#  |  renderHdr = use_api_decorator(*args, **kwargs)
#  |
#  |  renderVRT(self, outfile=None)
#  |      Renders a bare minimum ENVI HDR file, that can be used to directly ingest the outputs into a GIS package.
#  |
#  |  setByteOrder(self, byteOrder)
#  |
#  |  setCaster(self, accessMode, dataType)
#  |      # # Set the caster type if needed
#  |      # @param accessMode \c string access mode of the file. Can be 'read' or 'write'
#  |      # @param dataType \c string is the dataType from or to the caster writes or reads.
#  |
#  |  setDeltaLatitude(self, val)
#  |
#  |  setDeltaLongitude(self, val)
#  |
#  |  setFirstLatitude(self, val)
#  |
#  |  setFirstLongitude(self, val)
#  |
#  |  setImageType(self, val)
#  |
#  |  setLength(self, val)
#  |
#  |  setProduct(self, val)
#  |
#  |  setWidth(self, val)
#  |
#  |  setXmax(self, val)
#  |
#  |  setXmin(self, val)
#  |
#  |  toNumpyDataType(self)
#  |      # To facilitate the use of numpy to manipulate isce images
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from isceobj.Image.Image.Image:
#  |
#  |  deltaLatitude
#  |
#  |  deltaLongitude
#  |
#  |  extraFilename
#  |
#  |  firstLatitude
#  |
#  |  firstLongitude
#  |
#  |  length
#  |
#  |  width
#  |
#  |  xmax
#  |
#  |  xmin
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from isceobj.Image.Image.Image:
#  |
#  |  facility_list = (<iscesys.Component.Configurable.Configurable.Facility...
#  |
#  |  logging_name = 'isce.isceobj.Image.Image'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from iscesys.ImageApi.DataAccessorPy.DataAccessor:
#  |
#  |  __int__(self)
#  |      ## Experimental
#  |
#  |  checkLocation(self)
#  |
#  |  createAccessor(self)
#  |
#  |  createFile(self, lines)
#  |
#  |  finalizeAccessor(self)
#  |
#  |  getAccessMode(self)
#  |
#  |  getAccessor(self)
#  |
#  |  getBands(self)
#  |
#  |  getCaster(self)
#  |
#  |  getDataType(self)
#  |
#  |  getFileLength(self)
#  |
#  |  getFilename(self)
#  |
#  |  getGDALDataTypeId(self, type_)
#  |
#  |  getInterleavedScheme(self)
#  |
#  |  getSize(self)
#  |
#  |  getTypeSize(self)
#  |
#  |  initAccessor(self, filename, filemode, width, type=None, bands=None, scheme=None, caster=None)
#  |
#  |  methodSelector(self)
#  |
#  |  rewind(self)
#  |
#  |  setAccessMode(self, val)
#  |
#  |  setBands(self, val)
#  |
#  |  setDataType(self, val)
#  |
#  |  setExtraInfo(self, ei)
#  |
#  |  setFilename(self, val)
#  |
#  |  setInterleavedScheme(self, val)
#  |
#  |  uniquePath(self, paths)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from iscesys.ImageApi.DataAccessorPy.DataAccessor:
#  |
#  |  getTypeSizeS(type_)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from iscesys.ImageApi.DataAccessorPy.DataAccessor:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from iscesys.Component.Configurable.Configurable:
#  |
#  |  checkInitialization(self)
#  |
#  |  configure(self)
#  |      Public alias to _configureThis
#  |
#  |  extendParameterList(self, sup, sub)
#  |
#  |  facility(self, attrname, public_name=None, module=None, factory=None, doc=None, args=(), kwargs={}, mandatory=False, private=False)
#  |
#  |  get_mandatory_parameters(self)
#  |
#  |  get_optional_parameters(self)
#  |
#  |  get_parameter_dictionary(self, func=<function Configurable.<lambda> at 0x7efcc3708158>)
#  |      ## Build a dictionary of {attrname:value} -- basically a __dict__
#  |
#  |  get_parameter_names(self, func=<function Configurable.<lambda> at 0x7efcc37070d0>)
#  |
#  |  get_parameter_values(self, func=<function Configurable.<lambda> at 0x7efcc3708048>)
#  |
#  |  help(self)
#  |      Method that the developer may replace in order to give a helpful
#  |      message to the user
#  |
#  |  init(self, propDict=None, factDict=None, docDict=None, unitsDict=None)
#  |
#  |  initComponent(self, initObject)
#  |
#  |  initOptionalAndMandatoryLists(self)
#  |
#  |  initProperties(self, dictProp)
#  |      as for calling _facilities, if we make sure that this method is
#  |      called in the contructure we don't have to worry about this part
#  |      #set the defaults first and then overwrite with the values in dictProp
#  |      if property  present
#  |      try:
#  |          self._parameters()
#  |      except:# not implemented
#  |          pass
#  |
#  |  initRecursive(self, dictProp, dictFact)
#  |
#  |  isAskingHelp(self)
#  |
#  |  load(self, filename, parser='xml')
#  |
#  |  parameter(self, attrname, public_name=None, default=None, units=None, doc=None, container=None, type=None, mandatory=False, private=False, intent='input')
#  |
#  |  reformatDictionaryOfVariables(self)
#  |
#  |  renderToDictionary(self, obj, propDict, factDict, miscDict)
#  |
#  |  restoreAfterRendering(self)
#  |      #abstract method to be called after adaptToRender to repristinate the original format
#  |
#  |  setWarnings(self)
#  |
#  |  set_facility_attr(self, facility)
#  |      ## TBD method: passing a facility to youself should call it
#  |      ## and assign it? Thus, I think,
#  |      #map(self.set_facility_attr, self.facility_list) #should run everything?
#  |
#  |  unsetWarnings(self)
#  |
#  |  updatePrivate(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from iscesys.Component.Configurable.Configurable:
#  |
#  |  Facility = <class 'iscesys.Component.Configurable.Configurable.Facilit...
#  |      Parameter(attrname,
#  |      public_name="",
#  |      module=,
#  |      factory=,
#  |      args=(),
#  |      kwargs={},
#  |      mandatory=False,
#  |      doc="""Please provide a docstring""",
#  |      private=False):
#  |
#  |  METADATA_LOCATION = Parameter('metadatalocation', public_name='METAD.....
#  |      Parameter( attrname,
#  |      public_name="",
#  |      default=None,
#  |      container=None,
#  |      type=type,
#  |      mandatory=False,
#  |      units=None,
#  |      doc="""Please provide a docstring""",
#  |      private=False):
#  |
#  |  Parameter = <class 'iscesys.Component.Configurable.Configurable.Parame...
#  |      Parameter( attrname,
#  |      public_name="",
#  |      default=None,
#  |      container=None,
#  |      type=type,
#  |      mandatory=False,
#  |      units=None,
#  |      doc="""Please provide a docstring""",
#  |      private=False):
#  |
#  |  Variable = <class 'iscesys.Component.Configurable.Configurable.Variabl...
#  |      Variable(name, dtype, mandatory, key=None)
#  |
#  |      name is a sting
#  |      dtype is a type
#  |      mandatory is a bool
#  |
#  |      If key is set to a name, then that name will be associated
#  |      with the variable; otherwise, it is computed from "name"
#  |      in the NAME method.
#  |
#  |  __metaclass__ = <class 'iscesys.Component.Configurable.configurable'>
#  |      type(object_or_name, bases, dict)
#  |      type(object) -> the object's type
#  |      type(name, bases, dict) -> a new type
#  |
#  |  dt = <class 'datetime.datetime'>
#  |      datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#  |
#  |      The year, month and day arguments are required. tzinfo may be None, or an
#  |      instance of a tzinfo subclass. The remaining arguments may be ints.
#  |
#  |  port_list = ()

# %%
# !focus.py -h
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# usage: focus.py [-h] -i INDIR [-a AMBIGUITY] [-d DOPPLER]
#
# Focus from raw data to slc
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -i INDIR, --input INDIR
#                         Directory with raw file
#   -a AMBIGUITY, --amb AMBIGUITY
#                         Doppler ambiguities to add
#   -d DOPPLER, --dop DOPPLER
#                         Doppler to focus the image to.
